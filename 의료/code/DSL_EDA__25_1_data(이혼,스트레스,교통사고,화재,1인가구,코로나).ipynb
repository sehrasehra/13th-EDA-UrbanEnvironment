# %% [markdown]
# # **0. 데이터 불러오기**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import numpy as np
import pandas as pd

# %%
data_ca = pd.read_excel("/content/drive/MyDrive/DSL/DSL EDA 25-1/caraccident_city.xlsx")
data_d = pd.read_excel("/content/drive/MyDrive/DSL/DSL EDA 25-1/divorce_city.xlsx")
data_f = pd.read_excel("/content/drive/MyDrive/DSL/DSL EDA 25-1/fire_city.xlsx")
data_oh = pd.read_excel("/content/drive/MyDrive/DSL/DSL EDA 25-1/onephousehold_city.xlsx")
data_s = pd.read_excel("/content/drive/MyDrive/DSL/DSL EDA 25-1/stress_city.xlsx")
data_covid = pd.read_excel("/content/drive/MyDrive/DSL/DSL EDA 25-1/covid_city.xlsx", sheet_name=4,header=3)
# Out:
# /usr/local/lib/python3.11/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.11/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.11/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.11/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ...

# %% [markdown]
# # **1. 교통사고 발생 건수 데이터 정리**

# %%
data_ca.head()
# Out:
#    시도별(1)  월별(1)      2023    2023.1    2023.2      2022    2022.1    2022.2  \
# 0  시도별(1)  월별(1)  사고건수 (건)  사망자수 (명)  부상자수 (명)  사고건수 (건)  사망자수 (명)  부상자수 (명)
# 1      서울     전체     33811       180     45414     33698       221     45329
# 2     NaN     1월      2526        14      3407      2874        18      3868
# 3     NaN     2월      2279        15      3105      2176        16      2919
# 4     NaN     3월      2632        18      3442      2187        12      2852
#
#        2021    2021.1    2021.2
# 0  사고건수 (건)  사망자수 (명)  부상자수 (명)
# 1     33913       243     45223
# 2      2717        17      3690
# 3      2505        21      3334
# 4      2789        12      3740

# %%
data_ca
data_ca.drop(index=0, inplace=True)
data_ca=data_ca[data_ca['월별(1)']=='전체']
data_ca=data_ca[['시도별(1)', '2023','2022','2021']]
data_ca=data_ca.reset_index(drop=True)
data_ca
# Out:
#    시도별(1)   2023   2022   2021
# 0      서울  33811  33698  33913
# 1      부산  11003  10882  11339
# 2      대구  10880  11102  12133
# 3      인천   7648   7695   7912
# 4      광주   6972   7122   7543
# 5      대전   7398   6841   7027
# 6      울산   3664   3660   3801
# 7      세종   1166    932    788
# 8      경기  53164  52968  53332
# 9      강원   6079   6425   6605
# 10     충북   7939   7644   7985
# 11     충남   8606   8164   8423
# 12     전북   5830   5681   6112
# 13     전남   8287   8335   8685
# 14     경북  10777  11037  12100
# 15     경남  11122  10611  11059
# 16     제주   3950   4039   4373

# %%
data_ca_new=pd.concat([data_ca['2023'], data_ca['2022'], data_ca['2021']], ignore_index=True).to_frame(name='2023')
data_ca_new.rename(columns={'2023': '교통사고 발생 건수'}, inplace=True)

# %%
data_ca_new
# Out:
#    교통사고 발생 건수
# 0       33811
# 1       11003
# 2       10880
# 3        7648
# 4        6972
# 5        7398
# 6        3664
# 7        1166
# 8       53164
# 9        6079
# 10       7939
# 11       8606
# 12       5830
# 13       8287
# 14      10777
# 15      11122
# 16       3950
# 17      33698
# 18      10882
# 19      11102
# 20       7695
# 21       7122
# 22       6841
# 23       3660
# 24        932
# 25      52968
# 26       6425
# 27       7644
# 28       8164
# 29       5681
# 30       8335
# 31      11037
# 32      10611
# 33       4039
# 34      33913
# 35      11339
# 36      12133
# 37       7912
# 38       7543
# 39       7027
# 40       3801
# 41        788
# 42      53332
# 43       6605
# 44       7985
# 45       8423
# 46       6112
# 47       8685
# 48      12100
# 49      11059
# 50       4373

# %% [markdown]
# # **2. 이혼율 데이터 정리**

# %%
data_d.head()
# Out:
#      시도별 2023 2023.1 2022 2022.1 2021 2021.1
# 0    시도별   남편     아내   남편     아내   남편     아내
# 1     전국  4.1      4  4.2    4.1  4.5    4.5
# 2  서울특별시  3.1    2.9  3.2    3.1  3.7    3.5
# 3  부산광역시  3.8    3.7  3.8    3.7  4.3    4.2
# 4  대구광역시  3.8    3.9  3.6    3.7    4      4

# %% [markdown]
# 년도별 남편 이혼율, 아내 이혼율 존재 => 년도별 이혼율을 둘의 평균으로 정리함.

# %%
data_d.drop(index=[0,1], inplace=True)
data_d['2023Mean'] = data_d[['2023', '2023.1']].mean(axis=1)
data_d['2022Mean'] = data_d[['2022', '2022.1']].mean(axis=1)
data_d['2021Mean'] = data_d[['2021', '2021.1']].mean(axis=1)
data_d= data_d[["시도별","2023Mean","2022Mean","2021Mean"]]
data_d
# Out:
#         시도별 2023Mean 2022Mean 2021Mean
# 2     서울특별시      3.0     3.15      3.6
# 3     부산광역시     3.75     3.75     4.25
# 4     대구광역시     3.85     3.65      4.0
# 5     인천광역시      4.8      4.7     5.35
# 6     광주광역시      4.0     3.95      4.3
# 7     대전광역시     3.95      4.1      4.5
# 8     울산광역시      4.2      4.4      4.9
# 9   세종특별자치시     3.65     3.65     4.25
# 10      경기도      4.2      4.2      4.7
# 11  강원특별자치도     4.15      4.4     4.45
# 12     충청북도      4.5      4.5      4.6
# 13     충청남도      4.5      4.6      4.9
# 14     전라북도     4.25     4.15     4.55
# 15     전라남도     4.05      4.1      4.3
# 16     경상북도     4.05      4.0      4.2
# 17     경상남도     4.45     4.45     4.75
# 18  제주특별자치도     4.95      5.3      5.0

# %%
data_d_new=pd.concat([data_d['2023Mean'], data_d['2022Mean'], data_d['2021Mean']], ignore_index=True).to_frame(name='2023Mean')
data_d_new.rename(columns={'2023Mean': '이혼율'}, inplace=True)
data_d_new
# Out:
#      이혼율
# 0    3.0
# 1   3.75
# 2   3.85
# 3    4.8
# 4    4.0
# 5   3.95
# 6    4.2
# 7   3.65
# 8    4.2
# 9   4.15
# 10   4.5
# 11   4.5
# 12  4.25
# 13  4.05
# 14  4.05
# 15  4.45
# 16  4.95
# 17  3.15
# 18  3.75
# 19  3.65
# 20   4.7
# 21  3.95
# 22   4.1
# 23   4.4
# 24  3.65
# 25   4.2
# 26   4.4
# 27   4.5
# 28   4.6
# 29  4.15
# 30   4.1
# 31   4.0
# 32  4.45
# 33   5.3
# 34   3.6
# 35  4.25
# 36   4.0
# 37  5.35
# 38   4.3
# 39   4.5
# 40   4.9
# 41  4.25
# 42   4.7
# 43  4.45
# 44   4.6
# 45   4.9
# 46  4.55
# 47   4.3
# 48   4.2
# 49  4.75
# 50   5.0

# %% [markdown]
# # **3. 화재발생 건수 데이터 정리**

# %%
data_f.head()
# Out:
#   행정구역별(1)   2023   2022   2021
# 0       전국  38857  40113  36267
# 1    서울특별시   5671   5396   4951
# 2    부산광역시   2468   2488   2271
# 3    대구광역시   1293   1294   1189
# 4    인천광역시   1332   1279   1270

# %%
data_f.drop(index=0, inplace=True)
data_f=data_f.reset_index(drop=True)
data_f
# Out:
#    행정구역별(1)  2023  2022  2021
# 0     서울특별시  5671  5396  4951
# 1     부산광역시  2468  2488  2271
# 2     대구광역시  1293  1294  1189
# 3     인천광역시  1332  1279  1270
# 4     광주광역시   732   761   743
# 5     대전광역시  1021   964   796
# 6     울산광역시   794   923   802
# 7   세종특별자치시   219   231   185
# 8       경기도  8202  8604  8169
# 9   강원특별자치도  1977  1944  1780
# 10     충청북도  1480  1522  1382
# 11     충청남도  1980  2157  2015
# 12  전북특별자치도  2167  2156  1984
# 13     전라남도  2608  2925  2473
# 14     경상북도  2979  3237  2849
# 15     경상남도  3378  3620  2864
# 16  제주특별자치도   556   612   544

# %%
data_f_new=pd.concat([data_f['2023'], data_f['2022'], data_f['2021']], ignore_index=True).to_frame(name='2023')
data_f_new.rename(columns={'2023': '화재 발생 건수'}, inplace=True)
data_f_new
# Out:
#     화재 발생 건수
# 0       5671
# 1       2468
# 2       1293
# 3       1332
# 4        732
# 5       1021
# 6        794
# 7        219
# 8       8202
# 9       1977
# 10      1480
# 11      1980
# 12      2167
# 13      2608
# 14      2979
# 15      3378
# 16       556
# 17      5396
# 18      2488
# 19      1294
# 20      1279
# 21       761
# 22       964
# 23       923
# 24       231
# 25      8604
# 26      1944
# 27      1522
# 28      2157
# 29      2156
# 30      2925
# 31      3237
# 32      3620
# 33       612
# 34      4951
# 35      2271
# 36      1189
# 37      1270
# 38       743
# 39       796
# 40       802
# 41       185
# 42      8169
# 43      1780
# 44      1382
# 45      2015
# 46      1984
# 47      2473
# 48      2849
# 49      2864
# 50       544

# %% [markdown]
# # **4. 1인가구 비율 데이터 정리**

# %%
data_oh.head()
# Out:
#    행정구역별                 2023        2023.1        2023.2  \
# 0  행정구역별  1인가구비율(A÷B×100) (%)  1인가구(A) (가구)  일반가구(B) (가구)
# 1     전국                 35.5       7829035      22073158
# 2  서울특별시                 39.3       1627480       4141659
# 3  부산광역시                 36.4        532509       1462404
# 4  대구광역시                 34.7        359048       1033238
#
#                   2022        2022.1        2022.2                 2021  \
# 0  1인가구비율(A÷B×100) (%)  1인가구(A) (가구)  일반가구(B) (가구)  1인가구비율(A÷B×100) (%)
# 1                 34.5       7502350      21773507                 33.4
# 2                 38.2       1564187       4098818                 36.8
# 3                 35.3        511745       1447825                   34
# 4                 33.8        341667       1010834                 32.7
#
#          2021.1        2021.2
# 0  1인가구(A) (가구)  일반가구(B) (가구)
# 1       7165788      21448463
# 2       1489893       4046799
# 3        487362       1431365
# ...

# %%
data_oh.drop(index=[0,1], inplace=True)
data_oh=data_oh[["행정구역별","2023","2022","2021"]]
data_oh=data_oh.reset_index(drop=True)
data_oh
# Out:
#       행정구역별  2023  2022  2021
# 0     서울특별시  39.3  38.2  36.8
# 1     부산광역시  36.4  35.3    34
# 2     대구광역시  34.7  33.8  32.7
# 3     인천광역시  31.8    31    30
# 4     광주광역시  36.5  35.5  34.5
# 5     대전광역시  39.4  38.5  37.6
# 6     울산광역시  30.9  30.2  29.5
# 7   세종특별자치시    33  32.8  31.5
# 8       경기도  31.2  30.2  29.2
# 9   강원특별자치도  38.8  37.2  36.3
# 10     충청북도  38.5    37  36.3
# 11     충청남도  37.4  36.6  35.8
# 12  전북특별자치도  37.7  36.6  35.7
# 13     전라남도  37.1  36.1  35.3
# 14     경상북도  38.1    37    36
# 15     경상남도  34.7  33.7  32.7
# 16  제주특별자치도  33.7  33.4  32.7

# %%
data_oh_new=pd.concat([data_oh['2023'], data_oh['2022'], data_oh['2021']], ignore_index=True).to_frame(name='2023')
data_oh_new.rename(columns={'2023': '1인가구 비율'}, inplace=True)
data_oh_new
# Out:
#    1인가구 비율
# 0     39.3
# 1     36.4
# 2     34.7
# 3     31.8
# 4     36.5
# 5     39.4
# 6     30.9
# 7       33
# 8     31.2
# 9     38.8
# 10    38.5
# 11    37.4
# 12    37.7
# 13    37.1
# 14    38.1
# 15    34.7
# 16    33.7
# 17    38.2
# 18    35.3
# 19    33.8
# 20      31
# 21    35.5
# 22    38.5
# 23    30.2
# 24    32.8
# 25    30.2
# 26    37.2
# 27      37
# 28    36.6
# 29    36.6
# 30    36.1
# 31      37
# 32    33.7
# 33    33.4
# 34    36.8
# 35      34
# 36    32.7
# 37      30
# 38    34.5
# 39    37.6
# 40    29.5
# 41    31.5
# 42    29.2
# 43    36.3
# 44    36.3
# 45    35.8
# 46    35.7
# 47    35.3
# 48      36
# 49    32.7
# 50    32.7

# %% [markdown]
# # **5. 스트레스인지율 데이터 정리**

# %%
data_s.head()
# Out:
#    행정구역별  2023  2022  2021
# 0  서울특별시  27.1  25.7  28.0
# 1  부산광역시  23.9  22.8  25.7
# 2  대구광역시  23.8  22.6  24.2
# 3  인천광역시  27.0  26.3  29.5
# 4  광주광역시  24.7  25.9  27.7

# %%
data_s_new=pd.concat([data_s['2023'], data_s['2022'], data_s['2021']], ignore_index=True).to_frame(name='2023')
data_s_new.rename(columns={'2023': '스트레스인지율'}, inplace=True)
data_s_new
# Out:
#     스트레스인지율
# 0      27.1
# 1      23.9
# 2      23.8
# 3      27.0
# 4      24.7
# 5      28.3
# 6      25.8
# 7      25.8
# 8      27.7
# 9      27.2
# 10     26.3
# 11     27.7
# 12     26.5
# 13     25.6
# 14     23.9
# 15     24.5
# 16     23.5
# 17     25.7
# 18     22.8
# 19     22.6
# 20     26.3
# 21     25.9
# 22     24.5
# 23     21.9
# 24     20.1
# 25     24.6
# 26     25.5
# 27     25.2
# 28     25.4
# 29     24.9
# 30     21.5
# 31     23.4
# 32     23.1
# 33     25.0
# 34     28.0
# 35     25.7
# 36     24.2
# 37     29.5
# 38     27.7
# 39     24.0
# 40     24.8
# 41     25.5
# 42     28.1
# 43     28.3
# 44     27.2
# 45     27.0
# 46     26.2
# 47     23.7
# 48     24.7
# 49     24.9
# 50     25.3

# %% [markdown]
# # **6. 코로나 확진자 데이터 정리**

# %%
data_covid.head()
# Out:
#             Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                   일자       계(명)         서울         부산         대구         인천
# 1                누적(명)   34572554    6751335    2092642    1516421    1991892
# 2  2020-01-20 00:00:00          1          -          -          -          1
# 3  2020-01-21 00:00:00          0          -          -          -          -
# 4  2020-01-22 00:00:00          0          -          -          -          -
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0         광주         대전         울산         세종          경기          강원
# 1    1018499    1013275     738128     273413     9266797     1005836
# 2          -          -          -          -           -           -
# 3          -          -          -          -           -           -
# 4          -          -          -          -           -           -
#
# ...

# %%
data_covid.columns = data_covid.iloc[0]
data_covid = data_covid[1:]
data_covid = data_covid.drop(columns=['계(명)', '검역'])
data_covid.drop(index=[1], inplace=True)
data_covid.head()
# Out:
# 0                   일자 서울 부산 대구 인천 광주 대전 울산 세종 경기 강원 충북 충남 전북 전남 경북 경남 제주
# 2  2020-01-20 00:00:00  -  -  -  1  -  -  -  -  -  -  -  -  -  -  -  -  -
# 3  2020-01-21 00:00:00  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# 4  2020-01-22 00:00:00  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# 5  2020-01-23 00:00:00  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# 6  2020-01-24 00:00:00  1  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -

# %%
# 2021년도 시도별 코로나확진자 수 누적합
data_covid['Year'] = pd.to_datetime(data_covid['일자']).dt.year
df_2021 = data_covid[data_covid['Year'] == 2021]
df_2021sum = pd.DataFrame([df_2021.iloc[:, 1:-1].sum()]).T
df_2021sum.head()
# Out:
#          0
# 0
# 서울  206109
# 부산   23207
# 대구   15323
# 인천   33880
# 광주    6945

# %%
# 2022년도 시도별 코로나확진자 수 누적합
df_2022 = data_covid[data_covid['Year'] == 2022]
df_2022sum = pd.DataFrame([df_2022.iloc[:, 1:-1].sum()]).T
df_2022sum.head()
# Out:
#           0
# 0
# 서울  5436495
# 부산  1691534
# 대구  1245690
# 인천  1649641
# 광주   841026

# %%
# 2023년도 시도별 코로나확진자 수 누적합
df_2023 = data_covid[data_covid['Year'] == 2023]
df_2023sum1 = pd.DataFrame([df_2023.iloc[:238, 1:-1].sum()]).T #23년도 8월 26일까지 누적합 구하기
df_2023sum1
# Out:
#           0
# 0
# 서울  1057184
# 부산   367903
# 대구   238340
# 인천   293800
# 광주   163769
# 대전   159118
# 울산   116298
# 세종    41696
# 경기  1350606
# 강원   139999
# 충북   156350
# 충남   208667
# 전북   188042
# 전남   189016
# 경북   245238
# 경남   333365
# 제주    83804

# %%
# 23년도 9월 1일부터는 표본감시 체제 -> pdf 자료로만 존재. 이를 직접 데이터프레임으로 구현 후 누적합 계산.
data_sep = {
    "시도": ["서울", "부산", "대구", "인천", "광주", "대전", "울산", "세종", "경기", "강원", "충북", "충남", "전북", "전남", "경북", "경남", "제주"],
    "8월 5주": [2351, 671, 661, 1443, 499, 609, 474, 218, 5017, 738, 427, 1018, 529, 628, 919, 1284, 153],
    "9월 1주": [1828, 448, 512, 1124, 361, 393, 312, 154, 3679, 545, 410, 589, 403, 447, 692, 926, 120],
    "9월 2주": [1722, 462, 360, 952, 265, 346, 245, 137, 3334, 500, 325, 527, 349, 333, 603, 677, 101],
    "9월 3주": [1489, 371, 289, 849, 248, 298, 260, 103, 2691, 466, 311, 444, 283, 352, 497, 644, 92]
}

# DataFrame 생성
df_sep = pd.DataFrame(data_sep)
df_sep.head()
# Out:
#    시도  8월 5주  9월 1주  9월 2주  9월 3주
# 0  서울   2351   1828   1722   1489
# 1  부산    671    448    462    371
# 2  대구    661    512    360    289
# 3  인천   1443   1124    952    849
# 4  광주    499    361    265    248

# %%
data_oct_dec = {
    "시도": ["서울", "부산", "대구", "인천", "광주", "대전", "울산", "세종", "경기", "강원", "충북", "충남", "전북", "전남", "경북", "경남", "제주"],
    "9월 4주": [1284, 407, 347, 837, 261, 291, 262, 67, 2404, 446, 353, 414, 326, 373, 557, 716, 93],
    "10월 1주": [1157, 367, 304, 756, 225, 271, 204, 72, 2274, 462, 285, 453, 238, 331, 556, 588, 91],
    "10월 2주": [1170, 279, 244, 595, 226, 226, 157, 76, 2142, 399, 228, 289, 237, 333, 432, 491, 62],
    "10월 3주": [1143, 257, 282, 559, 185, 246, 152, 75, 2101, 359, 280, 320, 202, 239, 445, 447, 56],
    "10월 4주": [1261, 263, 315, 694, 241, 283, 156, 99, 2476, 398, 322, 393, 249, 295, 515, 584, 92],
    "11월 1주": [1264, 317, 343, 676, 283, 282, 175, 86, 2359, 441, 341, 403, 222, 339, 538, 555, 62],
    "11월 2주": [834, 240, 242, 474, 216, 262, 126, 62, 1607, 289, 225, 275, 192, 220, 464, 429, 64],
    "11월 3주": [892, 282, 248, 522, 214, 243, 125, 58, 1551, 264, 228, 219, 225, 235, 413, 404, 42],
    "11월 4주": [909, 300, 298, 586, 260, 246, 216, 135, 1674, 333, 253, 262, 208, 263, 443, 520, 76],
    "11월 5주": [790, 270, 294, 517, 261, 254, 212, 91, 1544, 303, 239, 245, 228, 241, 426, 548, 111],
    "12월 1주": [838, 274, 294, 518, 262, 256, 215, 91, 1587, 304, 239, 250, 228, 254, 426, 551, 100],
    "12월 2주": [878, 300, 274, 541, 260, 256, 170, 92, 1649, 302, 203, 239, 204, 204, 497, 584, 100],
    "12월 3주": [732, 249, 212, 405, 238, 213, 177, 64, 1376, 284, 201, 230, 174, 273, 459, 547, 66],
    "12월 4주": [671, 186, 166, 334, 187, 133, 144, 71, 1163, 200, 161, 129, 143, 206, 292, 396, 60]
}

# DataFrame 생성
df_oct_dec = pd.DataFrame(data_oct_dec)
df_oct_dec.head()
# Out:
#    시도  9월 4주  10월 1주  10월 2주  10월 3주  10월 4주  11월 1주  11월 2주  11월 3주  11월 4주  \
# 0  서울   1284    1157    1170    1143    1261    1264     834     892     909
# 1  부산    407     367     279     257     263     317     240     282     300
# 2  대구    347     304     244     282     315     343     242     248     298
# 3  인천    837     756     595     559     694     676     474     522     586
# 4  광주    261     225     226     185     241     283     216     214     260
#
#    11월 5주  12월 1주  12월 2주  12월 3주  12월 4주
# 0     790     838     878     732     671
# 1     270     274     300     249     186
# 2     294     294     274     212     166
# 3     517     518     541     405     334
# 4     261     262     260     238     187

# %%
df_covid_sep_dec = pd.merge(df_sep, df_oct_dec, on='시도', how="left") #23년도 9월~12월 데이터 생성.
df_covid_sep_dec = df_covid_sep_dec.set_index(df_covid_sep_dec.columns[0])
df_covid_sep_dec
# Out:
#     8월 5주  9월 1주  9월 2주  9월 3주  9월 4주  10월 1주  10월 2주  10월 3주  10월 4주  11월 1주  \
# 시도
# 서울   2351   1828   1722   1489   1284    1157    1170    1143    1261    1264
# 부산    671    448    462    371    407     367     279     257     263     317
# 대구    661    512    360    289    347     304     244     282     315     343
# 인천   1443   1124    952    849    837     756     595     559     694     676
# 광주    499    361    265    248    261     225     226     185     241     283
# 대전    609    393    346    298    291     271     226     246     283     282
# 울산    474    312    245    260    262     204     157     152     156     175
# 세종    218    154    137    103     67      72      76      75      99      86
# 경기   5017   3679   3334   2691   2404    2274    2142    2101    2476    2359
# 강원    738    545    500    466    446     462     399     359     398     441
# 충북    427    410    325    311    353     285     228     280     322     341
# ...

# %%
df_covid_sep_dec['sep_dec_Sum'] = df_covid_sep_dec.sum(axis=1)
df_2023sum2 = df_covid_sep_dec['sep_dec_Sum']
df_2023sum2
# Out:
# 시도
# 서울    21213
# 부산     5943
# 대구     5685
# 인천    12382
# 광주     4692
# 대전     5108
# 울산     3782
# 세종     1751
# 경기    40628
# 강원     7033
# 충북     5031
# 충남     6699
# 전북     4640
# 전남     5566
# 경북     9174
# 경남    10891
# 제주     1541
# Name: sep_dec_Sum, dtype: int64

# %%
df_2023sum = pd.concat([df_2023sum1, df_2023sum2], axis=1)
df_2023sum['2023sum'] = df_2023sum.sum(axis=1)
df_2023sum = df_2023sum['2023sum']
df_2023sum
# Out:
# 서울    1078397
# 부산     373846
# 대구     244025
# 인천     306182
# 광주     168461
# 대전     164226
# 울산     120080
# 세종      43447
# 경기    1391234
# 강원     147032
# 충북     161381
# 충남     215366
# 전북     192682
# 전남     194582
# 경북     254412
# 경남     344256
# 제주      85345
# Name: 2023sum, dtype: int64

# %%
data_covid_new = pd.concat([df_2023sum, df_2022sum, df_2021sum], axis=0, ignore_index=True)
data_covid_new.columns = ['코로나 확진자 수']
data_covid_new
# Out:
#     코로나 확진자 수
# 0     1078397
# 1      373846
# 2      244025
# 3      306182
# 4      168461
# 5      164226
# 6      120080
# 7       43447
# 8     1391234
# 9      147032
# 10     161381
# 11     215366
# 12     192682
# 13     194582
# 14     254412
# 15     344256
# 16      85345
# 17    5436495
# 18    1691534
# 19    1245690
# 20    1649641
# 21     841026
# 22     836323
# 23     611309
# 24     228054
# 25    7680724
# 26     847429
# 27     900824
# 28    1155658
# 29     963247
# 30     941437
# 31    1311391
# 32    1712297
# 33     361316
# 34     206109
# 35      23207
# 36      15323
# 37      33880
# 38       6945
# 39      11405
# 40       6200
# 41       1993
# 42     171882
# 43      11198
# 44      10335
# 45      16441
# 46       8731
# 47       5518
# 48      12890
# 49      19351
# 50       4222

# %% [markdown]
# ## **7. 데이터 합치기**

# %%
city=data_ca['시도별(1)'].to_numpy()
city=np.tile(city,3)
city
# Out:
# array(['서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', '강원', '충북',
#        '충남', '전북', '전남', '경북', '경남', '제주', '서울', '부산', '대구', '인천', '광주',
#        '대전', '울산', '세종', '경기', '강원', '충북', '충남', '전북', '전남', '경북', '경남',
#        '제주', '서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', '강원',
#        '충북', '충남', '전북', '전남', '경북', '경남', '제주'], dtype=object)

# %%
data_city=pd.DataFrame(city, columns=['시도별'])
data_city
# Out:
#    시도별
# 0   서울
# 1   부산
# 2   대구
# 3   인천
# 4   광주
# 5   대전
# 6   울산
# 7   세종
# 8   경기
# 9   강원
# 10  충북
# 11  충남
# 12  전북
# 13  전남
# 14  경북
# 15  경남
# 16  제주
# 17  서울
# 18  부산
# 19  대구
# 20  인천
# 21  광주
# 22  대전
# 23  울산
# 24  세종
# 25  경기
# 26  강원
# 27  충북
# 28  충남
# 29  전북
# 30  전남
# 31  경북
# 32  경남
# 33  제주
# 34  서울
# 35  부산
# 36  대구
# 37  인천
# 38  광주
# 39  대전
# 40  울산
# 41  세종
# 42  경기
# 43  강원
# 44  충북
# 45  충남
# 46  전북
# 47  전남
# 48  경북
# 49  경남
# 50  제주

# %%
data_final=pd.concat([data_city, data_d_new, data_s_new, data_ca_new, data_f_new, data_oh_new, data_covid_new], axis=1)
data_final
# Out:
#    시도별   이혼율  스트레스인지율 교통사고 발생 건수  화재 발생 건수 1인가구 비율  코로나 확진자 수
# 0   서울   3.0     27.1      33811      5671    39.3    1078397
# 1   부산  3.75     23.9      11003      2468    36.4     373846
# 2   대구  3.85     23.8      10880      1293    34.7     244025
# 3   인천   4.8     27.0       7648      1332    31.8     306182
# 4   광주   4.0     24.7       6972       732    36.5     168461
# 5   대전  3.95     28.3       7398      1021    39.4     164226
# 6   울산   4.2     25.8       3664       794    30.9     120080
# 7   세종  3.65     25.8       1166       219      33      43447
# 8   경기   4.2     27.7      53164      8202    31.2    1391234
# 9   강원  4.15     27.2       6079      1977    38.8     147032
# 10  충북   4.5     26.3       7939      1480    38.5     161381
# 11  충남   4.5     27.7       8606      1980    37.4     215366
# 12  전북  4.25     26.5       5830      2167    37.7     192682
# 13  전남  4.05     25.6       8287      2608    37.1     194582
# ...

# %%
data_final.to_excel('DSL EDA 25-1 data (이혼율,스트레스,교통사고,화재,1인,코로나).xlsx', index=False)
