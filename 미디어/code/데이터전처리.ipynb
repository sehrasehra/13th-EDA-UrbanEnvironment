# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#!sudo apt-get install -y fonts-nanum
#!sudo fc-cache -fv
#!rm ~/.cache/matplotlib -rf

# %%
import matplotlib.font_manager as fm
import os
import matplotlib.pyplot as plt

# apt-get : 패키지 설치 명령어
# -qq : 에러외의 메세지 숨기는 옵션키
# !apt-get -qq install fonts-nanum

# %%
fe = fm.FontEntry(
    fname=r'/usr/share/fonts/truetype/nanum/NanumGothic.ttf', # ttf 파일이 저장되어 있는 경로
    name='NanumGothic')                        # 이 폰트의 원하는 이름 설정
fm.fontManager.ttflist.insert(0, fe)              # Matplotlib에 폰트 추가
plt.rcParams.update({'font.size': 18, 'font.family': 'NanumGothic'}) # 폰트 설정

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
csv_file_path = "/content/merged2023.csv"
df = pd.read_csv(csv_file_path, encoding="utf-8-sig")

# %%
df
# Out:
#          BRDCST_DE CHNNEL_NM                 ADVRTS_MATR_NM  \
# 0         20230101      KBS2      맥도날드 (애니메이션/RMHC하우스/행운버거)
# 1         20230101      KBS2      맥도날드 (애니메이션/RMHC하우스/행운버거)
# 2         20230101      KBS2      맥도날드 (애니메이션/RMHC하우스/행운버거)
# 3         20230101      KBS2      맥도날드 (애니메이션/RMHC하우스/행운버거)
# 4         20230101      KBS2      맥도날드 (애니메이션/RMHC하우스/행운버거)
# ...            ...       ...                            ...
# 1133607   20231226       SBS     진천청주왕족발보쌈 (백년가게의맛/건강하고맛있게)
# 1133608   20231226       SBS  맥도날드 (NCT도영/행운버거를구매해주신/감사합니다)
# 1133609   20231226       SBS  맥도날드 (NCT도영/행운버거를구매해주신/감사합니다)
# 1133610   20231226       SBS  맥도날드 (NCT도영/행운버거를구매해주신/감사합니다)
# 1133611   20231226       SBS  맥도날드 (NCT도영/행운버거를구매해주신/감사합니다)
#
#          ADVRTS_BEGIN_TIME  ADVRTS_TIME ADVRTS_TY_NM  UNIT_ACCTO_ADVRTS_ODR  \
# 0                   125138           30   프로 A(정상요금)                      3
# 1                   125138           30   프로 A(정상요금)                      3
# 2                   125138           30   프로 A(정상요금)                      3
# 3                   125138           30   프로 A(정상요금)                      3
# 4                   125138           30   프로 A(정상요금)                      3
# ...                    ...          ...          ...                    ...
# 1133607              73313           20   토막 B(정상요금)                      2
# 1133608              73530           30   토막 B(정상요금)                      1
# 1133609              73530           30   토막 B(정상요금)                      1
# 1133610              73530           30   토막 B(정상요금)                      1
# 1133611              73530           30   토막 B(정상요금)                      1
#
#          UNIT_ACCTO_ADVRTS_CO INDUTY_SCLAS_NM            ADVRTS_TY_DC AREA_NM  \
# 0                           3          패스트푸드점  [슈퍼맨이돌아왔다(재)] {광고 / 후}      서울
# 1                           3          패스트푸드점  [슈퍼맨이돌아왔다(재)] {광고 / 후}      서울
# 2                           3          패스트푸드점  [슈퍼맨이돌아왔다(재)] {광고 / 후}   경기·인천
# 3                           3          패스트푸드점  [슈퍼맨이돌아왔다(재)] {광고 / 후}   경기·인천
# 4                           3          패스트푸드점  [슈퍼맨이돌아왔다(재)] {광고 / 후}   경기·인천
# ...                       ...             ...                     ...     ...
# 1133607                     3           대중음식점           [광고 / 07시39분]    충청북도
# 1133608                     5          패스트푸드점           [광고 / 07시39분]     제주도
# 1133609                     5          패스트푸드점           [광고 / 07시39분]     제주도
# 1133610                     5          패스트푸드점           [광고 / 07시39분]     제주도
# 1133611                     5          패스트푸드점           [광고 / 07시39분]     제주도
#
#         ANALS_TRGET_NM  TVGRP_CO  frequency
# 0                   가구         1          0
# 1                   개인         0          0
# 2                   가구         1          0
# 3                   개인         0          0
# 4             유료매체가입가구         1          0
# ...                ...       ...        ...
# 1133607       유료매체가입개인         3          1
# 1133608             가구         0          1
# 1133609             개인         0          1
# 1133610       유료매체가입가구         0          1
# 1133611       유료매체가입개인         0          1
#
# [1133612 rows x 14 columns]

# %% [markdown]
# #1. 방송일자 문자열 --> 날짜형으로 변경

# %%
# BRDCST_DE를 문자열로 변환한 후 날짜로 변환
df['BRDCST_DE'] = pd.to_datetime(df['BRDCST_DE'].astype(str), format='%Y%m%d', errors='coerce')

# %%
# 1: 월(`YYYY-MM`) 정보 추출
df['month'] = pd.to_datetime(df['BRDCST_DE']).dt.to_period('M')  # 'YYYY-MM' 형식 추출

# %%
# 2: 월별 GRP 평균 계산
monthly_grp = df.groupby('month')['TVGRP_CO'].mean().reset_index()

# %%
# 3: 그래프로 트렌드 시각화
plt.figure(figsize=(12, 7))
plt.plot(
    monthly_grp['month'].astype(str),
    monthly_grp['TVGRP_CO'],
    marker='o',
    linestyle='-',
    linewidth=2,
    color='#1f77b4',
    label="Average GRP"
)

plt.title("Monthly GRP Trend (January to December)", fontsize=16, fontweight='bold')
plt.xlabel("Month (YYYY-MM)", fontsize=14)
plt.ylabel("Average GRP", fontsize=14)

plt.xticks(fontsize=12, rotation=45)
plt.yticks(fontsize=12)

mean_grp = monthly_grp['TVGRP_CO'].mean()
plt.axhline(mean_grp, color='red', linestyle='--', linewidth=1.5, label=f"Overall Mean: {mean_grp:.2f}")

plt.legend(fontsize=12)

plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.7)

plt.tight_layout()
plt.show()

# %%
#월별 칼럼 필요없으니 drop.
df = df.drop(columns=["month"])

# %% [markdown]
# # 광고유형명(TV_NM) 전처리

# %% [markdown]
# ### 1. 시간(hour)추출

# %%
# 광고 시작 시간을 HH:MM:SS 형식으로 변환
#df['ADVRTS_BEGIN_TIME'] = df['ADVRTS_BEGIN_TIME'].astype(str).str.zfill(6)  # 6자리 숫자로 변환
#df['ADVRTS_BEGIN_TIME'] = pd.to_datetime(df['ADVRTS_BEGIN_TIME'], format='%H%M%S', errors='coerce').dt.time

# %%
# 'ADVRTS_BEGIN_TIME'을 문자열(6자리)로 변환
#df['ADVRTS_BEGIN_TIME'] = df['ADVRTS_BEGIN_TIME'].astype(str).str.zfill(6)

#def convert_time_format(time_str):
    #"""24시 이상인 시간을 00~23시 형식으로 변환"""
    #if len(time_str) == 6:
        #hour = int(time_str[:2])  # 앞 2자리: 시(hour)
        #minute = time_str[2:4]  # 중간 2자리: MM
        #second = time_str[4:6]  # 마지막 2자리: SS
        #if hour >= 24:  # 24시 이상이면 24를 빼서 변환
            #hour -= 24
        #return f"{hour:02d}:{minute}:{second}"  # 변환된 HH:MM:SS 값 반환
    #return time_str  # 변환 불가능한 경우 원래 값을 그대로 반환

# 변환 적용
#df['CORRECTED_BEGIN_TIME'] = df['ADVRTS_BEGIN_TIME'].apply(convert_time_format)

# HH:MM:SS 형식으로 변환하여 적용
#df['ADVRTS_BEGIN_TIME'] = pd.to_datetime(df['CORRECTED_BEGIN_TIME'], format='%H:%M:%S', errors='coerce').dt.time

# %%
# 광고 시작 시간에서 시간(hour)만 추출
#df['ADVRTS_HOUR'] = pd.to_datetime(df['ADVRTS_BEGIN_TIME'], format='%H:%M:%S', errors='coerce').dt.hour

# %%
# 변환 후 결측치 개수 확인
#missing_values = df[['ADVRTS_BEGIN_TIME', 'ADVRTS_HOUR']].isnull().sum()

# 결측치 개수 출력
#print("결측치 개수 확인:")
#print(missing_values)

# %% [markdown]
# # 2. TYPE / SALE / CLASS 열 생성 후 TY_NM DROP

# %%
# 광고 유형명 전처리 (불필요한 공백 제거)
df["ADVRTS_TY_NM"] = df["ADVRTS_TY_NM"].str.strip()

# %%
import numpy as np
import pandas as pd

# 조건에 따른 광고 종류 문자열 생성
conditions = [
    df["ADVRTS_TY_NM"].str.contains("ID|곧이어", regex=True),  # 자막 광고
    df["ADVRTS_TY_NM"].str.contains("토막", regex=True),         # 토막 광고
    df["ADVRTS_TY_NM"].str.contains("프로", regex=True),          # 프로 광고
]
choices = ["자막", "토막", "프로"]

df["TYPE_STR"] = np.select(conditions, choices, default="오류")

# One-Hot Encoding 적용 (오류 값은 별도로 처리하거나 제외할 수 있음)
# df = pd.get_dummies(df, columns=["TYPE_STR"], prefix="TYPE")

# %%
# SALE 열 생성: '할인'이면 1, 아니면 0
#df["SALE"] = np.where(df["ADVRTS_TY_NM"].str.contains("할인"), 1, 0)

# 원-핫 인코딩 적용: SALE 열을 기준으로 새로운 더미 변수 생성
#df = pd.get_dummies(df, columns=["SALE"], prefix="SALE")

# %%
import pandas as pd

# CLASS 열 생성: ADVRTS_TY_NM 열에서 A, B, C, SA 추출
df["CLASS"] = df["ADVRTS_TY_NM"].str.extract(r"(A|B|C|SA)")

# 원-핫 인코딩 적용: CLASS 열을 기준으로 새로운 더미 변수 생성
#df = pd.get_dummies(df, columns=["CLASS"], prefix="CLASS")

# %%
# 기존 광고 유형명 열 삭제
df.drop(columns=["ADVRTS_TY_NM"], inplace=True)

# %% [markdown]
# # 3. TY_DC (광고유형설명; 위치)

# %%
df["AD_POSITION_LABEL"] = np.select(
    [
        df["ADVRTS_TY_DC"].astype(str).str.contains("전", na=False),       # 광고 전
        df["ADVRTS_TY_DC"].astype(str).str.contains("후", na=False),       # 광고 후
        df["ADVRTS_TY_DC"].astype(str).str.contains("프로", na=False)   # 광고 프로그램
    ],
    ["전", "후", "프로"],
    default="중간"  # 위 조건에 해당하지 않으면 중간으로 처리
)

# %%
grp_means = df.groupby("AD_POSITION_LABEL")["TVGRP_CO"].mean()
print(grp_means)
# Out:
# AD_POSITION_LABEL
# 전     1.300794
# 중간    2.264829
# 프로    1.743590
# 후     1.952137
# Name: TVGRP_CO, dtype: float64

# %% [markdown]
# 중간 > 프로 > 후 > 전

# %%
# df = pd.get_dummies(df, columns=["AD_POSITION_LABEL"], prefix="AD_POS")

# %%
#기존 광고유형설명(TY_DC) 열 삭제
df.drop(columns=["ADVRTS_TY_DC"], inplace=True)

# %%
df.head()
# Out:
#    BRDCST_DE CHNNEL_NM             ADVRTS_MATR_NM  ADVRTS_BEGIN_TIME  \
# 0 2023-01-01      KBS2  맥도날드 (애니메이션/RMHC하우스/행운버거)             125138
# 1 2023-01-01      KBS2  맥도날드 (애니메이션/RMHC하우스/행운버거)             125138
# 2 2023-01-01      KBS2  맥도날드 (애니메이션/RMHC하우스/행운버거)             125138
# 3 2023-01-01      KBS2  맥도날드 (애니메이션/RMHC하우스/행운버거)             125138
# 4 2023-01-01      KBS2  맥도날드 (애니메이션/RMHC하우스/행운버거)             125138
#
#    ADVRTS_TIME  UNIT_ACCTO_ADVRTS_ODR  UNIT_ACCTO_ADVRTS_CO INDUTY_SCLAS_NM  \
# 0           30                      3                     3          패스트푸드점
# 1           30                      3                     3          패스트푸드점
# 2           30                      3                     3          패스트푸드점
# 3           30                      3                     3          패스트푸드점
# 4           30                      3                     3          패스트푸드점
#
#   AREA_NM ANALS_TRGET_NM  TVGRP_CO  frequency TYPE_STR CLASS AD_POSITION_LABEL
# 0      서울             가구         1          0       프로     A                 후
# 1      서울             개인         0          0       프로     A                 후
# 2   경기·인천             가구         1          0       프로     A                 후
# 3   경기·인천             개인         0          0       프로     A                 후
# 4   경기·인천       유료매체가입가구         1          0       프로     A                 후

# %% [markdown]
# ## NLP스러운거..

# %%
#!pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading jpype1-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.11/dist-packages (from konlpy) (5.3.0)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.11/dist-packages (from konlpy) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from JPype1>=0.7.0->konlpy) (24.2)
# Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 38.1 MB/s eta 0:00:00
# Downloading jpype1-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (494 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.1/494.1 kB 27.5 MB/s eta 0:00:00
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.5.2 konlpy-0.6.0

# %% [markdown]
# ## TF-IDF 분석: 가장 많이 등장하는 단어를 확인

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
# NaN 값 제거 후 리스트 변환
advert_texts = df["ADVRTS_MATR_NM"].dropna().tolist()

# CountVectorizer: 단어 등장 빈도 분석
vectorizer = CountVectorizer(max_features=20, stop_words="english")  # 상위 20개 단어만 분석
X = vectorizer.fit_transform(advert_texts)

# 단어별 등장 횟수 출력
word_freq = dict(zip(vectorizer.get_feature_names_out(), X.toarray().sum(axis=0)))
print("📊 광고 문구에서 가장 많이 등장한 단어:", word_freq)
# Out:
# 📊 광고 문구에서 가장 많이 등장한 단어: {'60계치킨': 126437, 'id자막': 35337, '가상': 76469, '고기맛은두께다': 50406, '곧이어자막': 67351, '그냥좋은거야': 39447, '뉴진스': 39318, '마동석': 39447, '맥도날드': 255070, '브릿지': 41972, '신나는데이유가어딨어': 39447, '아웃백스테이크하우스': 97330, '아이브': 51237, '안먹어봤구나': 51237, '이젠': 51237, '자담치킨': 47940, '정해인': 38606, '파파존스': 51237, '푸라닭치킨': 38666, '한양화로': 90194}

# %% [markdown]
# ## WordCloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# 광고 문구 텍스트 합치기
text = " ".join(advert_texts)

# 워드클라우드 생성
# Update the font path to a known working font if NanumGothic is not installed
wordcloud = WordCloud(font_path='/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf',
                      width=800, height=400, background_color="white").generate(text)

# 시각화
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# NLP 끝. 이거는 쓰기 힘드니까 드랍.

# %%
df.drop(columns=["ADVRTS_MATR_NM"], inplace=True)

# %%
df.columns
# Out:
# Index(['BRDCST_DE', 'CHNNEL_NM', 'ADVRTS_MATR_NM', 'ADVRTS_BEGIN_TIME',
#        'ADVRTS_TIME', 'UNIT_ACCTO_ADVRTS_ODR', 'UNIT_ACCTO_ADVRTS_CO',
#        'INDUTY_SCLAS_NM', 'AREA_NM', 'ANALS_TRGET_NM', 'TVGRP_CO', 'frequency',
#        'TYPE_STR', 'CLASS', 'AD_POSITION_LABEL'],
#       dtype='object')

# %%
df
# Out:
#          BRDCST_DE CHNNEL_NM                 ADVRTS_MATR_NM  \
# 0       2023-01-01      KBS2      맥도날드 (애니메이션/RMHC하우스/행운버거)
# 1       2023-01-01      KBS2      맥도날드 (애니메이션/RMHC하우스/행운버거)
# 2       2023-01-01      KBS2      맥도날드 (애니메이션/RMHC하우스/행운버거)
# 3       2023-01-01      KBS2      맥도날드 (애니메이션/RMHC하우스/행운버거)
# 4       2023-01-01      KBS2      맥도날드 (애니메이션/RMHC하우스/행운버거)
# ...            ...       ...                            ...
# 1133607 2023-12-26       SBS     진천청주왕족발보쌈 (백년가게의맛/건강하고맛있게)
# 1133608 2023-12-26       SBS  맥도날드 (NCT도영/행운버거를구매해주신/감사합니다)
# 1133609 2023-12-26       SBS  맥도날드 (NCT도영/행운버거를구매해주신/감사합니다)
# 1133610 2023-12-26       SBS  맥도날드 (NCT도영/행운버거를구매해주신/감사합니다)
# 1133611 2023-12-26       SBS  맥도날드 (NCT도영/행운버거를구매해주신/감사합니다)
#
#          ADVRTS_BEGIN_TIME  ADVRTS_TIME  UNIT_ACCTO_ADVRTS_ODR  \
# 0                   125138           30                      3
# 1                   125138           30                      3
# 2                   125138           30                      3
# 3                   125138           30                      3
# 4                   125138           30                      3
# ...                    ...          ...                    ...
# 1133607              73313           20                      2
# 1133608              73530           30                      1
# 1133609              73530           30                      1
# 1133610              73530           30                      1
# 1133611              73530           30                      1
#
#          UNIT_ACCTO_ADVRTS_CO INDUTY_SCLAS_NM AREA_NM ANALS_TRGET_NM  \
# 0                           3          패스트푸드점      서울             가구
# 1                           3          패스트푸드점      서울             개인
# 2                           3          패스트푸드점   경기·인천             가구
# 3                           3          패스트푸드점   경기·인천             개인
# 4                           3          패스트푸드점   경기·인천       유료매체가입가구
# ...                       ...             ...     ...            ...
# 1133607                     3           대중음식점    충청북도       유료매체가입개인
# 1133608                     5          패스트푸드점     제주도             가구
# 1133609                     5          패스트푸드점     제주도             개인
# 1133610                     5          패스트푸드점     제주도       유료매체가입가구
# 1133611                     5          패스트푸드점     제주도       유료매체가입개인
#
#          TVGRP_CO  frequency TYPE_STR CLASS AD_POSITION_LABEL
# 0               1          0       프로     A                 후
# 1               0          0       프로     A                 후
# 2               1          0       프로     A                 후
# 3               0          0       프로     A                 후
# 4               1          0       프로     A                 후
# ...           ...        ...      ...   ...               ...
# 1133607         3          1       토막     B                중간
# 1133608         0          1       토막     B                중간
# 1133609         0          1       토막     B                중간
# 1133610         0          1       토막     B                중간
# 1133611         0          1       토막     B                중간
#
# [1133612 rows x 15 columns]

# %%
df.drop(columns=["ADVRTS_BEGIN_TIME", "CHNNEL_NM",
                 "INDUTY_SCLAS_NM", "BRDCST_DE", "AREA_NM", "ANALS_TRGET_NM"], inplace=True)

# %%
df.head()
# Out:
#    ADVRTS_TIME  UNIT_ACCTO_ADVRTS_ODR  UNIT_ACCTO_ADVRTS_CO  TVGRP_CO  \
# 0           30                      3                     3         1
# 1           30                      3                     3         0
# 2           30                      3                     3         1
# 3           30                      3                     3         0
# 4           30                      3                     3         1
#
#    frequency  TYPE_자막  TYPE_토막  TYPE_프로  CLASS_A  CLASS_B  CLASS_C  CLASS_SA  \
# 0          0    False    False     True     True    False    False     False
# 1          0    False    False     True     True    False    False     False
# 2          0    False    False     True     True    False    False     False
# 3          0    False    False     True     True    False    False     False
# 4          0    False    False     True     True    False    False     False
#
#    AD_POS_전  AD_POS_중간  AD_POS_프로  AD_POS_후
# 0     False      False      False      True
# 1     False      False      False      True
# 2     False      False      False      True
# 3     False      False      False      True
# 4     False      False      False      True

# %%
df
# Out:
#          ADVRTS_TIME  UNIT_ACCTO_ADVRTS_ODR  UNIT_ACCTO_ADVRTS_CO  TVGRP_CO  \
# 0                 30                      3                     3         1
# 1                 30                      3                     3         0
# 2                 30                      3                     3         1
# 3                 30                      3                     3         0
# 4                 30                      3                     3         1
# ...              ...                    ...                   ...       ...
# 1133607           20                      2                     3         3
# 1133608           30                      1                     5         0
# 1133609           30                      1                     5         0
# 1133610           30                      1                     5         0
# 1133611           30                      1                     5         0
#
#          frequency  TYPE_자막  TYPE_토막  TYPE_프로  CLASS_A  CLASS_B  CLASS_C  \
# 0                0    False    False     True     True    False    False
# 1                0    False    False     True     True    False    False
# 2                0    False    False     True     True    False    False
# 3                0    False    False     True     True    False    False
# 4                0    False    False     True     True    False    False
# ...            ...      ...      ...      ...      ...      ...      ...
# 1133607          1    False     True    False    False     True    False
# 1133608          1    False     True    False    False     True    False
# 1133609          1    False     True    False    False     True    False
# 1133610          1    False     True    False    False     True    False
# 1133611          1    False     True    False    False     True    False
#
#          CLASS_SA  AD_POS_전  AD_POS_중간  AD_POS_프로  AD_POS_후
# 0           False     False      False      False      True
# 1           False     False      False      False      True
# 2           False     False      False      False      True
# 3           False     False      False      False      True
# 4           False     False      False      False      True
# ...           ...       ...        ...        ...       ...
# 1133607     False     False       True      False     False
# 1133608     False     False       True      False     False
# 1133609     False     False       True      False     False
# 1133610     False     False       True      False     False
# 1133611     False     False       True      False     False
#
# [1133612 rows x 16 columns]

# %%
save_path = "/content/drive/MyDrive/visual.csv"
df.to_csv(save_path, index=False, encoding="utf-8-sig")
